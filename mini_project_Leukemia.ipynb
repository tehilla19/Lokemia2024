# %%
# Import necessary libraries
import numpy as np # For working with numbers, data structures and operations on numbers
import pandas as pd # For tables
import seaborn as sns # Seaborn library used for statistical data visualization.
import matplotlib.pyplot as plt # Allows us to plot graphs
from sklearn.datasets import load_breast_cancer # Contains various databases
import matplotlib.pyplot as plt
#for predictive data analysis=find patterns that might predict future behavior.

# %% [markdown]
# נעלה את הדאטא- ונבצע EDA
